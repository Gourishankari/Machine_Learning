# %% [markdown]
# *My First Program*

# %%
print("I am Gouri")
# Out:
# I am Gouri

# %%
a+b

# %% [markdown]
# **Variable Delcaration in Python**
# Rule1:Variable should always start with an alphabet or _
# Rule2:Varaible should not start with some number or specail characters Ex:1stnum=5
# Rule3:Varaible declaration is case sensitive
# Name name NamE
# Name=90
# Name=70

# %%
a=5
b=9
sum=a+b
print(sum)
print("sum")
# Out:
# 14
# sum

# %%
  diff=a-b
# Out:
# -4

# %% [markdown]
# **Variable Declaration in Python**

# %%
a=4
b=5
diff=a-b
print(diff)
print("diff")
# Out:
# -1
# diff

# %%
dif=a-b-c

# %% [markdown]
# Variable Declaration in Python

# %%
a=10
b=3
c=2
dif=a-b-c
print(dif)
# Out:
# 5

# %%
mul=a*b

# %% [markdown]
# Variable Delcaration inPython

# %%
a=43
b=5
mul=a*b
print(mul)
# Out:
# 215

# %%
div=a/b

# %% [markdown]
# Variable Declaration in Python

# %%
a=105
b=5
div=a/b
print(div)
# Out:
# 21.0

# %%
div1=a%b

# %% [markdown]
# Variable Declaration in Python

# %%
from binascii import b2a_base64
a=120
b=6
div1=a%b
print(div1)
# Out:
# 0

# %%
squ=a*a

# %% [markdown]
# Varaible Declaration in Python

# %%
a=67
squ=a*a
print(squ)
# Out:
# 4489

# %% [markdown]
# sroot=a**0.5

# %% [markdown]
# Varaible Declaration in Python

# %%
a=4
sroot=a**0.5
print(sroot)
# Out:
# 2.0

# %% [markdown]
# **sum of 2 square num**

# %%
a=10
b=5
sum=(a*a)+(b*b)
print(sum)
# Out:
# 125

# %% [markdown]
# Day 4 proceedings
# **Data types**

# %%
name="Gouri"
print(type(name))
# Out:
# <class 'str'>

# %%
name2="Gouri & 123"
print(type(name2))
# Out:
# <class 'str'>

# %% [markdown]
# **Numeric data type**

# %%
num1=10
num2=0.99
num3=4j
num4=-99
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>

# %% [markdown]
# sequence data type
# Lists
# Tuples
# range
#
# 1.ordered
# 2.Mutable
# 3.Allow duplicates

# %%
lis=['gouri','123','30.45']
type(lis)
# Out:
# list

# %%
print(lis)
# Out:
# ['gouri', '123', '30.45']

# %%
lis2=['patil','200','india','patil']
print(len(lis))
print(len(lis2))
lis3=lis+lis2
print(lis3)
print(len(lis3))
# Out:
# 3
# 4
# ['gouri', '123', '30.45', 'patil', '200', 'india', 'patil']
# 7

# %%
lis2.append("Hubli")

# %%
lis2
# Out:
# ['patil',
#  '200',
#  'india',
#  'patil',
#  'Hubli',
#  'Rabbit',
#  'Rabbit',
#  'Hubli',
#  'Rabbit',
#  'Hubli',
#  'Hubli']

# %%
lis=['gg','aa','bb','kle']
lis[0]
# Out:
# 'gg'

# %%
lis[2]
# Out:
# 'bb'

# %%
lis.sort()

# %%
lis
# Out:
# ['aa', 'bb', 'gg', 'kle']

# %%
tuple1=("Hubli","Belagum","Hubli")
print(type(tuple1))
tuple2=("Hubli",)
print(type(tuple2))
tuple3=(1,2,3,4,5)
print(type(tuple3))
tuple4=("asdf","123",1,1,2,3,5,True)
print(type(tuple4))

tuple5=tuple((1,2,3,4,5))
print(type(tuple5))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %% [markdown]
# Tuples --> storing multiple items in a single varaible
# 1.Ordered
# 2.Unchangeable
# 3.Allow duplicates
